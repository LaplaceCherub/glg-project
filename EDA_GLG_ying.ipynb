# %% [markdown]
# ## Datasets: Annotated corpus for Named Entity Recognition

# %% [markdown]
# ### $\S1$ . Dataset Overview
#
# **Source:** https://www.kaggle.com/datasets/abhinavwalia95/entity-annotated-corpus
#
# **Context:**
# Annotated Corpus for Named Entity Recognition is extract from GMB([Groningen Meaning Bank](https://developer.ibm.com/exchanges/data/all/groningen-meaning-bank/)) corpus. The dataset contains only documents authored by Voice of America VOA, together with documents from the MASC dataset and the CIA World Factbook.
#
# The datasets (`ner_dataset.csv` and `ner.csv`) represent a tokenized corpus. It is tagged, annotated and built specifically to train a model to predict named entities such as name, location, etc.

# %% [markdown]
# Words in the sentence are tagged using the [IOB](https://en.wikipedia.org/wiki/Inside%E2%80%93outside%E2%80%93beginning_(tagging)) format:
#
# - B - {CHUNK_TYPE} – for the word in the Beginning chunk
# - I - {CHUNK_TYPE} – for words Inside the chunk
# - O – Outside any chunk
#
# The IOB tags are further classified into the following classes –
#
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %% [markdown]
# For the POS column, see [Penn Treebank Part-of-Speech tagset](https://www.sketchengine.eu/penn-treebank-tagset/) for the details.

# %% [markdown]
# ### $\S2$. Load the dataset
#
# - One skipped line:  `line 281837: expected 25 fields, saw 34\n' in `ner.csv`

# %%
import pandas as pd

# %%
print(f"Pandas version:{pd.__version__}")
# Out:
# Pandas version:1.3.4

# %%
ner_df = pd.read_csv("./datasets/ner.csv", encoding='latin1', on_bad_lines="warn") 
dataset_df = pd.read_csv("./datasets/ner_dataset.csv", encoding='latin1') # utf-8 failed
# Out:
# b'Skipping line 281837: expected 25 fields, saw 34\n'

# %%
print(f"The shape of the table dataset_df is: {dataset_df.shape}")
dataset_df.head()
# Out:
# The shape of the table dataset_df is: (1048575, 4)
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
print(f"The shape of the table ner_df is: {ner_df.shape}")
ner_df.head()
# Out:
# The shape of the table ner_df is: (1050795, 25)
#    Unnamed: 0     lemma next-lemma next-next-lemma next-next-pos  \
# 0           0  thousand         of        demonstr           NNS
# 1           1        of   demonstr            have           VBP
# 2           2  demonstr       have           march           VBN
# 3           3      have      march         through            IN
# 4           4     march    through          london           NNP
#
#   next-next-shape next-next-word next-pos next-shape      next-word  ...  \
# 0       lowercase  demonstrators       IN  lowercase             of  ...
# 1       lowercase           have      NNS  lowercase  demonstrators  ...
# 2       lowercase        marched      VBP  lowercase           have  ...
# 3       lowercase        through      VBN  lowercase        marched  ...
# 4     capitalized         London       IN  lowercase        through  ...
#
#   prev-prev-lemma prev-prev-pos prev-prev-shape prev-prev-word   prev-shape  \
# 0      __start2__    __START2__        wildcard     __START2__     wildcard
# 1      __start1__    __START1__        wildcard     __START1__  capitalized
# 2        thousand           NNS     capitalized      Thousands    lowercase
# 3              of            IN       lowercase             of    lowercase
# 4        demonstr           NNS       lowercase  demonstrators    lowercase
#
#        prev-word sentence_idx        shape           word tag
# 0     __START1__          1.0  capitalized      Thousands   O
# 1      Thousands          1.0    lowercase             of   O
# 2             of          1.0    lowercase  demonstrators   O
# 3  demonstrators          1.0    lowercase           have   O
# 4           have          1.0    lowercase        marched   O
#
# [5 rows x 25 columns]

# %% [markdown]
# ### $\S3$. Initial inspection on two datasets: choose `ner_dataset.csv` over `ner.csv`
#
# We inspected two datasets, and found that the dataset `ner.csv` **missing sentences from `sentence_idx = 18617` to  `sentence_idx=31399`.**
#
# To fill the missing values, we need to rederive them from `ner.csv`. Hence, it makes sense to simply discard `ner.csv` and do EDA and feature engineer on the more primitive and complete dataset `ner.csv`.
#
# For the details, see the code in this section below.

# %%
ner_df.sample(10)
# Out:
#         Unnamed: 0     lemma next-lemma next-next-lemma next-next-pos  \
# 145193      145193       sea     should              at            IN
# 895355      893135    inflat          .        __end1__      __END1__
# 847700      845480         .   __end1__        __end2__      __END2__
# 955477      953257       has    rekindl         concern           NNS
# 375646       93811     first       made             the            DT
# 846612      844392         a        new            film            NN
# 786070      783850         ,       weak          govern            NN
# 5691          5691        in         an       interview            NN
# 835054      832834      gaza      strip            have           VBP
# 668271      386436  forecast     expect              it           PRP
#
#        next-next-shape next-next-word  next-pos   next-shape  next-word  ...  \
# 145193       lowercase             at        MD    lowercase     should  ...
# 895355        wildcard       __END1__         .        punct          .  ...
# 847700        wildcard       __END2__  __END1__     wildcard   __END1__  ...
# 955477       lowercase       concerns       VBN    lowercase  rekindled  ...
# 375646       lowercase            the       VBD    lowercase       made  ...
# 846612       lowercase           film        JJ    lowercase        new  ...
# 786070       lowercase     government        JJ    lowercase       weak  ...
# 5691         lowercase      interview        DT    lowercase         an  ...
# 835054       lowercase           have       NNP  capitalized      Strip  ...
# 668271       lowercase             it       VBP    lowercase     expect  ...
#
#        prev-prev-lemma prev-prev-pos prev-prev-shape prev-prev-word  \
# 145193              up            RP       lowercase             up
# 895355              up            RP       lowercase             up
# 847700             for            IN       lowercase            for
# 955477             the            DT     capitalized            The
# 375646         russian            JJ     capitalized        Russian
# 846612      __start2__    __START2__        wildcard     __START2__
# 786070              of            IN       lowercase             of
# 5691        __start2__    __START2__        wildcard     __START2__
# 835054              in            IN       lowercase             in
# 668271               ,             ,           punct              ,
#
#        prev-shape   prev-word sentence_idx        shape         word    tag
# 145193  lowercase          at       6616.0    lowercase          sea      O
# 895355  lowercase        with      40792.0    lowercase    inflation      O
# 847700  lowercase         him      38633.0        punct            .      O
# 955477  lowercase    homicide      43571.0    lowercase          has      O
# 375646  lowercase      leader       4273.0    lowercase        first      O
# 846612   wildcard  __START1__      38586.0    uppercase            A      O
# 786070  lowercase  corruption      35829.0        punct            ,      O
# 5691     wildcard  __START1__        260.0  capitalized           In      O
# 835054  lowercase         the      38068.0  capitalized         Gaza  B-geo
# 668271  lowercase         but      17667.0    lowercase  forecasters      O
#
# [10 rows x 25 columns]

# %% [markdown]
# There are some missing values in `ner.csv`

# %%
ner_df.isnull().sum()
# Out:
# Unnamed: 0         0
# lemma              0
# next-lemma         0
# next-next-lemma    0
# next-next-pos      0
# next-next-shape    0
# next-next-word     0
# next-pos           0
# next-shape         1
# next-word          1
# pos                1
# prev-iob           1
# prev-lemma         1
# prev-pos           1
# prev-prev-iob      1
# prev-prev-lemma    1
# prev-prev-pos      1
# prev-prev-shape    1
# prev-prev-word     1
# prev-shape         1
# prev-word          1
# sentence_idx       1
# shape              1
# word               1
# tag                1
# dtype: int64

# %% [markdown]
# Select the row with missing values

# %%
ner_df[ner_df.isnull().any(axis=1)]
# Out:
#         Unnamed: 0  lemma next-lemma next-next-lemma next-next-pos  \
# 689433      407598  domin    countri               .             .
#
#        next-next-shape next-next-word next-pos next-shape next-word  ...  \
# 689433           punct        .nister        O        NaN       NaN  ...
#
#        prev-prev-lemma prev-prev-pos prev-prev-shape prev-prev-word  \
# 689433             NaN           NaN             NaN            NaN
#
#        prev-shape prev-word sentence_idx shape word  tag
# 689433        NaN       NaN          NaN   NaN  NaN  NaN
#
# [1 rows x 25 columns]

# %% [markdown]
# Print out rows around the row with missing values.

# %%
row_w_nan = 689433
ner_df.iloc[row_w_nan-22: row_w_nan+5]
# Out:
#         Unnamed: 0       lemma  next-lemma next-next-lemma next-next-pos  \
# 689411      407576        iran          's       state-run            JJ
# 689412      407577          's   state-run         televis            NN
# 689413      407578   state-run     televis        saturday           NNP
# 689414      407579     televis    saturday            quot           VBD
# 689415      407580    saturday        quot        khamenei           NNP
# 689416      407581        quot    khamenei              as            IN
# 689417      407582    khamenei          as             say           VBG
# 689418      407583          as         say          nation           NNS
# 689419      407584         say      nation            must            MD
# 689420      407585      nation        must            have            VB
# 689421      407586        must        have          altern            JJ
# 689422      407587        have      altern          energi            NN
# 689423      407588      altern      energi           sourc           NNS
# 689424      407589      energi       sourc              to            TO
# 689425      407590       sourc          to           avoid            VB
# 689426      407591          to       avoid              be           VBG
# 689427      407592       avoid          be              at            IN
# 689428      407593          be          at             the            DT
# 689429      407594          at         the           merci            NN
# 689430      407595         the       merci              of            IN
# 689431      407596       merci          of           domin           VBG
# 689432      407597          of       domin         countri           NNS
# 689433      407598       domin     countri               .             .
# 689434      687214      pascal  yoadimadji             has           VBZ
# 689435      687215  yoadimadji         has             die           VBN
# 689436      687216         has         die              in            IN
# 689437      687217         die          in            pari           NNP
#
#         next-next-shape next-next-word next-pos       next-shape    next-word  \
# 689411  contains-hyphen      state-run      POS            other           's
# 689412        lowercase     television       JJ  contains-hyphen    state-run
# 689413      capitalized       Saturday       NN        lowercase   television
# 689414        lowercase         quoted      NNP      capitalized     Saturday
# 689415      capitalized       Khamenei      VBD        lowercase       quoted
# 689416        lowercase             as      NNP      capitalized     Khamenei
# 689417        lowercase         saying       IN        lowercase           as
# 689418        lowercase        nations      VBG        lowercase       saying
# 689419        lowercase           must      NNS        lowercase      nations
# 689420        lowercase           have       MD        lowercase         must
# 689421        lowercase      alternate       VB        lowercase         have
# 689422        lowercase         energy       JJ        lowercase    alternate
# 689423        lowercase        sources       NN        lowercase       energy
# 689424        lowercase             to      NNS        lowercase      sources
# 689425        lowercase          avoid       TO        lowercase           to
# 689426        lowercase          being       VB        lowercase        avoid
# 689427        lowercase             at      VBG        lowercase        being
# 689428        lowercase            the       IN        lowercase           at
# 689429        lowercase          mercy       DT        lowercase          the
# 689430        lowercase             of       NN        lowercase        mercy
# 689431        lowercase    domineering       IN        lowercase           of
# 689432        lowercase      countries      VBG        lowercase  domineering
# 689433            punct        .nister        O              NaN          NaN
# 689434        lowercase            has      NNP      capitalized   Yoadimadji
# 689435        lowercase           died      VBZ        lowercase          has
# 689436        lowercase             in      VBN        lowercase         died
# 689437      capitalized          Paris       IN        lowercase           in
#
#         ... prev-prev-lemma prev-prev-pos  prev-prev-shape prev-prev-word  \
# 689411  ...      __start2__    __START2__         wildcard     __START2__
# 689412  ...      __start1__    __START1__         wildcard     __START1__
# 689413  ...            iran           NNP      capitalized           Iran
# 689414  ...              's           POS            other             's
# 689415  ...       state-run            JJ  contains-hyphen      state-run
# 689416  ...         televis            NN        lowercase     television
# 689417  ...        saturday           NNP      capitalized       Saturday
# 689418  ...            quot           VBD        lowercase         quoted
# 689419  ...        khamenei           NNP      capitalized       Khamenei
# 689420  ...              as            IN        lowercase             as
# 689421  ...             say           VBG        lowercase         saying
# 689422  ...          nation           NNS        lowercase        nations
# 689423  ...            must            MD        lowercase           must
# 689424  ...            have            VB        lowercase           have
# 689425  ...          altern            JJ        lowercase      alternate
# 689426  ...          energi            NN        lowercase         energy
# 689427  ...           sourc           NNS        lowercase        sources
# 689428  ...              to            TO        lowercase             to
# 689429  ...           avoid            VB        lowercase          avoid
# 689430  ...              be           VBG        lowercase          being
# 689431  ...              at            IN        lowercase             at
# 689432  ...             the            DT        lowercase            the
# 689433  ...             NaN           NaN              NaN            NaN
# 689434  ...           prime            JJ      capitalized          Prime
# 689435  ...          minist            NN      capitalized       Minister
# 689436  ...          pascal           NNP      capitalized         Pascal
# 689437  ...      yoadimadji           NNP      capitalized     Yoadimadji
#
#              prev-shape   prev-word sentence_idx            shape        word  \
# 689411         wildcard  __START1__      18616.0      capitalized        Iran
# 689412      capitalized        Iran      18616.0            other          's
# 689413            other          's      18616.0  contains-hyphen   state-run
# 689414  contains-hyphen   state-run      18616.0        lowercase  television
# 689415        lowercase  television      18616.0      capitalized    Saturday
# 689416      capitalized    Saturday      18616.0        lowercase      quoted
# 689417        lowercase      quoted      18616.0      capitalized    Khamenei
# 689418      capitalized    Khamenei      18616.0        lowercase          as
# 689419        lowercase          as      18616.0        lowercase      saying
# 689420        lowercase      saying      18616.0        lowercase     nations
# 689421        lowercase     nations      18616.0        lowercase        must
# 689422        lowercase        must      18616.0        lowercase        have
# 689423        lowercase        have      18616.0        lowercase   alternate
# 689424        lowercase   alternate      18616.0        lowercase      energy
# 689425        lowercase      energy      18616.0        lowercase     sources
# 689426        lowercase     sources      18616.0        lowercase          to
# 689427        lowercase          to      18616.0        lowercase       avoid
# 689428        lowercase       avoid      18616.0        lowercase       being
# 689429        lowercase       being      18616.0        lowercase          at
# 689430        lowercase          at      18616.0        lowercase         the
# 689431        lowercase         the      18616.0        lowercase       mercy
# 689432        lowercase       mercy      18616.0        lowercase          of
# 689433              NaN         NaN          NaN              NaN         NaN
# 689434      capitalized    Minister      31399.0      capitalized      Pascal
# 689435      capitalized      Pascal      31399.0      capitalized  Yoadimadji
# 689436      capitalized  Yoadimadji      31399.0        lowercase         has
# 689437        lowercase         has      31399.0        lowercase        died
#
#           tag
# 689411  B-geo
# 689412      O
# 689413      O
# 689414      O
# 689415  B-tim
# 689416      O
# 689417  B-per
# 689418      O
# 689419      O
# 689420      O
# 689421      O
# 689422      O
# 689423      O
# 689424      O
# 689425      O
# 689426      O
# 689427      O
# 689428      O
# 689429      O
# 689430      O
# 689431      O
# 689432      O
# 689433    NaN
# 689434  B-per
# 689435  I-per
# 689436      O
# 689437      O
#
# [27 rows x 25 columns]

# %% [markdown]
# It seems like the last row of sentence 18616. So we want to look at sentence 18616 in the other dataset `ner_dataset.csv`

# %%
dataset_df.loc[dataset_df["Sentence #"]=="Sentence: 18616"]
# Out:
#              Sentence #  Word  POS    Tag
# 407576  Sentence: 18616  Iran  NNP  B-geo

# %%
dataset_df.iloc[407576: 407610]
# Out:
#              Sentence #         Word  POS    Tag
# 407576  Sentence: 18616         Iran  NNP  B-geo
# 407577              NaN           's  POS      O
# 407578              NaN    state-run   JJ      O
# 407579              NaN   television   NN      O
# 407580              NaN     Saturday  NNP  B-tim
# 407581              NaN       quoted  VBD      O
# 407582              NaN     Khamenei  NNP  B-per
# 407583              NaN           as   IN      O
# 407584              NaN       saying  VBG      O
# 407585              NaN      nations  NNS      O
# 407586              NaN         must   MD      O
# 407587              NaN         have   VB      O
# 407588              NaN    alternate   JJ      O
# 407589              NaN       energy   NN      O
# 407590              NaN      sources  NNS      O
# 407591              NaN           to   TO      O
# 407592              NaN        avoid   VB      O
# 407593              NaN        being  VBG      O
# 407594              NaN           at   IN      O
# 407595              NaN          the   DT      O
# 407596              NaN        mercy   NN      O
# 407597              NaN           of   IN      O
# 407598              NaN  domineering  VBG      O
# 407599              NaN    countries  NNS      O
# 407600              NaN            .    .      O
# 407601  Sentence: 18617     Khamenei  NNP  B-per
# 407602              NaN       lashed  VBD      O
# 407603              NaN          out   RP      O
# 407604              NaN           at   IN      O
# 407605              NaN      critics  NNS      O
# 407606              NaN           of   IN      O
# 407607              NaN         Iran  NNP  B-geo
# 407608              NaN           's  POS      O
# 407609              NaN      nuclear   JJ      O

# %% [markdown]
# Here we realize that sentences from 18616 to 31399 are missing from `ner.csv`

# %%
ner_df.loc[ner_df["sentence_idx"] == 200000]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, lemma, next-lemma, next-next-lemma, next-next-pos, next-next-shape, next-next-word, next-pos, next-shape, next-word, pos, prev-iob, prev-lemma, prev-pos, prev-prev-iob, prev-prev-lemma, prev-prev-pos, prev-prev-shape, prev-prev-word, prev-shape, prev-word, sentence_idx, shape, word, tag]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ### $\S 4$ EDA on `ner_dataset.csv`

# %% [markdown]
# #### $\S 4.0$ Basic information

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Sentence #  47959 non-null    object
#  1   Word        1048575 non-null  object
#  2   POS         1048575 non-null  object
#  3   Tag         1048575 non-null  object
# dtypes: object(4)
# memory usage: 32.0+ MB

# %%
dataset_df.describe()  ## POS = NN:  noun, singular or mass
# Out:
#          Sentence #     Word      POS      Tag
# count         47959  1048575  1048575  1048575
# unique        47959    35178       42       17
# top     Sentence: 1      the       NN        O
# freq              1    52573   145807   887908

# %%
dataset_df.head(10)
# Out:
#     Sentence #           Word  POS    Tag
# 0  Sentence: 1      Thousands  NNS      O
# 1          NaN             of   IN      O
# 2          NaN  demonstrators  NNS      O
# 3          NaN           have  VBP      O
# 4          NaN        marched  VBN      O
# 5          NaN        through   IN      O
# 6          NaN         London  NNP  B-geo
# 7          NaN             to   TO      O
# 8          NaN        protest   VB      O
# 9          NaN            the   DT      O

# %% [markdown]
# #### $\S 4.1$ Number of words in each Tag and POS

# %% [markdown]
# **Tags**

# %%
dataset_df["Tag"].value_counts()
# Out:
# B-geo    37644
# B-tim    20333
# B-org    20143
# I-per    17251
# B-per    16990
# I-org    16784
# B-gpe    15870
# I-geo     7414
# I-tim     6528
# B-art      402
# B-eve      308
# I-art      297
# I-eve      253
# B-nat      201
# I-gpe      198
# I-nat       51
# Name: Tag, dtype: int64

# %% [markdown]
# Plot the number of words that are tagged as the beginning of each type: "B-geo", "B-tim", "B-org", "B-per", "B-gpe", "B-art","B-eve", "B-nat"

# %%
dataset_df[dataset_df["Tag"].isin(["B-geo", "B-tim", "B-org", "B-per", "B-gpe", "B-art","B-eve", "B-nat"])]["Tag"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Look at some of the tags

# %%
dataset_df_gpe = dataset_df[dataset_df["Tag"] == "B-gpe"]

# %%
dataset_df_gpe.head()
# Out:
#     Sentence #     Word  POS    Tag
# 18         NaN  British   JJ  B-gpe
# 102        NaN  English   JJ  B-gpe
# 113        NaN  Britain  NNP  B-gpe
# 126        NaN  British   JJ  B-gpe
# 173        NaN     Iran  NNP  B-gpe

# %%
dataset_df_art = dataset_df[dataset_df["Tag"] == "B-art"]

# %%
dataset_df_art.head()
# Out:
#      Sentence #       Word  POS    Tag
# 263         NaN    Nuclear  NNP  B-art
# 3769        NaN   Saltillo  NNP  B-art
# 3810        NaN  Pentastar  NNP  B-art
# 3814        NaN   Chrysler  NNP  B-art
# 3816        NaN      Dodge  NNP  B-art

# %% [markdown]
# **POS**

# %%
dataset_df["POS"].value_counts()
# Out:
# NN      145807
# NNP     131426
# IN      120996
# DT       98454
# JJ       78412
# NNS      75840
# .        47831
# VBD      39379
# ,        32757
# VBN      32328
# VBZ      24960
# CD       24695
# VB       24211
# CC       23716
# TO       23061
# RB       20252
# VBG      19125
# VBP      16158
# PRP      13318
# POS      11257
# PRP$      8655
# MD        6973
# ``        3728
# WDT       3698
# JJS       3034
# JJR       2967
# WP        2542
# NNPS      2521
# RP        2490
# WRB       2184
# $         1149
# RBR       1055
# :          795
# RRB        679
# LRB        678
# EX         663
# RBS        296
# ;          214
# PDT        147
# WP$         99
# UH          24
# FW           1
# Name: POS, dtype: int64

# %%
dataset_df["POS"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### $\S4.2$ Analysis on sentences

# %% [markdown]
# **Total number of sentences: 47959**

# %%
dataset_df_sentences = dataset_df[dataset_df["Sentence #"].notnull()]

# %%
total_num_sentences = dataset_df_sentences.shape[0]

# %%
print(total_num_sentences)
# Out:
# 47959

# %% [markdown]
# **Analysis on the length of the sentences**

# %%
dataset_df_sentences
# Out:
#               Sentence #       Word  POS    Tag
# 0            Sentence: 1  Thousands  NNS      O
# 24           Sentence: 2   Families  NNS      O
# 54           Sentence: 3       They  PRP      O
# 68           Sentence: 4     Police  NNS      O
# 83           Sentence: 5        The   DT      O
# ...                  ...        ...  ...    ...
# 1048501  Sentence: 47955     Indian   JJ  B-gpe
# 1048521  Sentence: 47956     Indian   JJ  B-gpe
# 1048545  Sentence: 47957        Two   CD      O
# 1048556  Sentence: 47958       They  PRP      O
# 1048567  Sentence: 47959     Indian   JJ  B-gpe
#
# [47959 rows x 4 columns]

# %%
sentences_len = []
df_sentences_idx = dataset_df_sentences.index
for idx in range(total_num_sentences - 1):
    sentences_len.append(df_sentences_idx[idx+1] - df_sentences_idx[idx])
# last sentence 
sentences_len.append(dataset_df.shape[0] - df_sentences_idx[-1] + 1)

# %%
df_sentences_len = pd.DataFrame(sentences_len, columns=["Sentence Length"])
df_sentences_len["Sentence#"] = [i for i in range(1, total_num_sentences+1)]

# %%
df_sentences_len
# Out:
#        Sentence Length  Sentence#
# 0                   24          1
# 1                   30          2
# 2                   14          3
# 3                   15          4
# 4                   25          5
# ...                ...        ...
# 47954               20      47955
# 47955               24      47956
# 47956               11      47957
# 47957               11      47958
# 47958                9      47959
#
# [47959 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(9, 7)})
sns.distplot(df_sentences_len["Sentence Length"], bins=30)
# Out:
# /Users/yinghu/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sentence Length', ylabel='Density'>

# %%
df_sentences_len.boxplot("Sentence Length", grid=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### $\S5$. Questions:
